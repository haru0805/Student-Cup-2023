# %%
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
OUTPUT_DIR = '/content/drive/MyDrive/signate/Student Cup 2023/output'

df_024 = pd.read_csv(os.path.join(OUTPUT_DIR, 'submission-024.csv'), header=None)
df_024.columns = ["id", "price"]

df_024
# Out:
#           id         price
# 0      27532   9300.395172
# 1      27533   5181.374709
# 2      27534   5726.534327
# 3      27535  18736.007609
# 4      27536   4137.765190
# ...      ...           ...
# 27532  55064  12920.163482
# 27533  55065   8898.081880
# 27534  55066   6325.709139
# 27535  55067   4995.160711
# 27536  55068   5434.529912
#
# [27537 rows x 2 columns]

# %%
OUTPUT_DIR = '/content/drive/MyDrive/signate/Student Cup 2023/output'

df_044 = pd.read_csv(os.path.join(OUTPUT_DIR, 'submission-44-NN.csv'), header=None)
df_044.columns = ["id", "price"]

df_044
# Out:
#           id       price
# 0      27532   8517.2850
# 1      27533   4812.1310
# 2      27534   4787.8380
# 3      27535  17214.5500
# 4      27536   4067.8157
# ...      ...         ...
# 27532  55064  14120.3730
# 27533  55065  11520.1910
# 27534  55066   7036.6550
# 27535  55067   4414.2275
# 27536  55068   4478.7285
#
# [27537 rows x 2 columns]

# %%
OUTPUT_DIR = '/content/drive/MyDrive/signate/Student Cup 2023/output'

df_025 = pd.read_csv(os.path.join(OUTPUT_DIR, 'submission-025.csv'), header=None)
df_025.columns = ["id", "price"]
df_025
# Out:
#           id         price
# 0      27532   9293.735058
# 1      27533   5754.672094
# 2      27534   5795.170204
# 3      27535  18883.545419
# 4      27536   3978.482090
# ...      ...           ...
# 27532  55064  12691.687495
# 27533  55065   8916.752395
# 27534  55066   6386.543957
# 27535  55067   4896.267346
# 27536  55068   5613.030839
#
# [27537 rows x 2 columns]

# %%
OUTPUT_DIR = '/content/drive/MyDrive/signate/Student Cup 2023/output'

df_035 = pd.read_csv(os.path.join(OUTPUT_DIR, 'submission-035-NN.csv'), header=None)
df_035.columns = ["id", "price"]
df_035
# Out:
#           id       price
# 0      27532   7641.6196
# 1      27533   4500.8394
# 2      27534   4195.2740
# 3      27535  15998.7660
# 4      27536   3448.1750
# ...      ...         ...
# 27532  55064  13093.5440
# 27533  55065  10123.9720
# 27534  55066   6136.5280
# 27535  55067   3841.8770
# 27536  55068   4007.3940
#
# [27537 rows x 2 columns]

# %%
OUTPUT_DIR = '/content/drive/MyDrive/signate/Student Cup 2023/output'

df_038 = pd.read_csv(os.path.join(OUTPUT_DIR, 'submission-38-NN.csv'), header=None)
df_038.columns = ["id", "price"]
df_038
# Out:
#           id       price
# 0      27532   8282.3920
# 1      27533   4952.3335
# 2      27534   4545.7173
# 3      27535  17329.1130
# 4      27536   4018.9575
# ...      ...         ...
# 27532  55064  13566.1150
# 27533  55065  11581.6200
# 27534  55066   6663.6836
# 27535  55067   4286.1216
# 27536  55068   4645.0913
#
# [27537 rows x 2 columns]

# %%
OUTPUT_DIR = '/content/drive/MyDrive/signate/Student Cup 2023/output'

df_041 = pd.read_csv(os.path.join(OUTPUT_DIR, 'submission-41-NN.csv'), header=None)
df_041.columns = ["id", "price"]
df_041
# Out:
#           id       price
# 0      27532   9089.2600
# 1      27533   4869.2390
# 2      27534   4862.7620
# 3      27535  18275.6760
# 4      27536   4307.4033
# ...      ...         ...
# 27532  55064  14471.6280
# 27533  55065  13323.2480
# 27534  55066   6964.1160
# 27535  55067   4518.7620
# 27536  55068   4782.4453
#
# [27537 rows x 2 columns]

# %%
df_sub = df_024

# %%
df = df_024["price"]*0.55 + df_038["price"]*0.1 + df_025["price"]*0.35
df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-55_038-1_025-35.csv"), index=False, header=False)
df_sub.head(10)
# Out:
#       id         price
# 0  27532   8858.857543
# 1  27533   5409.666499
# 2  27534   5257.905456
# 3  27535  18215.139479
# 4  27536   3995.886516
# 5  27537  10193.438150
# 6  27538   3316.910282
# 7  27539   4926.215039
# 8  27540   3130.103856
# 9  27541   4595.967509

# %%
df = df_038["price"]*0.6 + df_025["price"]*0.4
df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-038-6_025-4.csv"), index=False, header=False)
df_sub.head(10)
# Out:
#       id         price
# 0  27532   8686.929223
# 1  27533   5273.268938
# 2  27534   5045.498462
# 3  27535  17950.885968
# 4  27536   4002.767336
# 5  27537  10972.554816
# 6  27538   3389.166789
# 7  27539   5025.074203
# 8  27540   3163.132066
# 9  27541   4518.021373

# %%
df = df_024["price"]*0.6 + df_038["price"]*0.2 + df_035["price"]*0.2
df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-6_038-2_035-2.csv"), index=False, header=False)
df_sub.head(10)
# Out:
#       id         price
# 0  27532   8581.399245
# 1  27533   4992.629831
# 2  27534   4975.689944
# 3  27535  17662.791604
# 4  27536   3945.143244
# 5  27537  10453.591158
# 6  27538   3323.770748
# 7  27539   4863.174446
# 8  27540   3286.915838
# 9  27541   4348.768827

# %%
df = df_024["price"]*0.6 + df_038["price"]*0.4

df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-6_038-4.csv"), index=False, header=False)
df_sub
# Out:
#           id         price
# 0      27532   8461.796347
# 1      27533   4976.511298
# 2      27534   4803.700886
# 3      27535  17529.320163
# 4      27536   3974.668946
# ...      ...           ...
# 27532  55064  13338.401562
# 27533  55065  10731.122772
# 27534  55066   6517.445417
# 27535  55067   4407.929943
# 27536  55068   4773.932187
#
# [27537 rows x 2 columns]

# %%
df = df_024["price"]*0.7 + df_038["price"]*0.3

df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-7_038-3.csv"), index=False, header=False)
df_sub
# Out:
#           id         price
# 0      27532   8407.975043
# 1      27533   4969.257959
# 2      27534   4726.305810
# 3      27535  17469.258014
# 4      27536   3987.955512
# ...      ...           ...
# 27532  55064  13406.715593
# 27533  55065  10986.271941
# 27534  55066   6561.316872
# 27535  55067   4371.387440
# 27536  55068   4735.279921
#
# [27537 rows x 2 columns]

# %%
df = df_024["price"]*0.5 + df_038["price"]*0.5

df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-5_038-5.csv"), index=False, header=False)
df_sub
# Out:
#           id         price
# 0      27532   8345.183522
# 1      27533   4960.795729
# 2      27534   4636.011555
# 3      27535  17399.185507
# 4      27536   4003.456506
# ...      ...           ...
# 27532  55064  13486.415297
# 27533  55065  11283.945970
# 27534  55066   6612.500236
# 27535  55067   4328.754520
# 27536  55068   4690.185611
#
# [27537 rows x 2 columns]

# %%
df = df_024["price"]*0.65 + df_038["price"]*0.35

df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-65_038-35.csv"), index=False, header=False)
df_sub
# Out:
#           id         price
# 0      27532   8323.206489
# 1      27533   4957.833949
# 2      27534   4604.408566
# 3      27535  17374.660129
# 4      27536   4008.881854
# ...      ...           ...
# 27532  55064  13514.310193
# 27533  55065  11388.131881
# 27534  55066   6630.414413
# 27535  55067   4313.832998
# 27536  55068   4674.402602
#
# [27537 rows x 2 columns]

# %%
df = df_024["price"]*0.55 + df_038["price"]*0.45

df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-55_038-45.csv"), index=False, header=False)
df_sub
# Out:
#           id         price
# 0      27532   8304.839969
# 1      27533   4955.358747
# 2      27534   4577.997496
# 3      27535  17354.163921
# 4      27536   4013.415895
# ...      ...           ...
# 27532  55064  13537.622356
# 27533  55065  11475.201534
# 27534  55066   6645.385547
# 27535  55067   4301.362869
# 27536  55068   4661.212516
#
# [27537 rows x 2 columns]

# %%
df = df_024["price"]*0.6 + df_041["price"]*0.4

df_sub["price"] = df

df_sub.to_csv(os.path.join(OUTPUT_DIR, "submission-024-6_041-4.csv"), index=False, header=False)
df_sub
# Out:
#           id         price
# 0      27532   8618.607981
# 1      27533   4920.910848
# 2      27534   4691.903298
# 3      27535  17722.768753
# 4      27536   4131.010857
# ...      ...           ...
# 27532  55064  13911.224614
# 27533  55065  12214.420121
# 27534  55066   6772.877728
# 27535  55067   4388.322521
# 27536  55068   4709.705630
#
# [27537 rows x 2 columns]
